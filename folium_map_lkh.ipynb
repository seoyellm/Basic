# %% [markdown]
# <font size=6>Folium Map 시각화

# %% [markdown]
# * GeoBand :  https://compas.lh.or.kr/api/python#%ED%8C%A8%ED%82%A4%EC%A7%80-%EC%82%AC%EC%9A%A9
# * Folium : https://python-visualization.github.io/folium/index.html
# * Google Console : https://console.cloud.google.com/

# %%
# ! pip install folium
# ! pip install googlemaps

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns


sns.set()

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
# from IPython.core.display import display, HTML
from IPython.display import display, HTML

display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# <style>.container{width:100% !important;}</style>

# %%
import folium
from folium import plugins
import re
import googlemaps
import pprint

# %% [markdown]
# # Folium

# %% [markdown]
# ## map

# %% [markdown]
# ## Marker

# %%
map = folium.Map(location=[37.5666805, 126.9784147], zoom_start=14, 
                 tiles='OpenStreetMap')  #Stamen Terrain')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_158799dfe2c797376ae551b0b58c5d6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_158799dfe2c797376ae551b0b58c5d6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_158799dfe2c797376ae551b0b58c5d6a = L.map(
#                 &quot;map_158799dfe2c797376ae551b0b58c5d6a&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d221f147f4365d091a99941ee9e64b70 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_158799dfe2c797376ae551b0b58c5d6a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tooltip = "클릭시 장소명 보여줄게"

folium.Marker(
    [37.5666805, 126.9784147], 
    popup="<i>시청</i>", 
    tooltip=tooltip,
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_158799dfe2c797376ae551b0b58c5d6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_158799dfe2c797376ae551b0b58c5d6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_158799dfe2c797376ae551b0b58c5d6a = L.map(
#                 &quot;map_158799dfe2c797376ae551b0b58c5d6a&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d221f147f4365d091a99941ee9e64b70 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_158799dfe2c797376ae551b0b58c5d6a);
#
#
#             var marker_3f4809678e3aa17630bd2603430416a0 = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_158799dfe2c797376ae551b0b58c5d6a);
#
#
#             var icon_e7d15c8f4121a015c8e7233c2c049446 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3f4809678e3aa17630bd2603430416a0.setIcon(icon_e7d15c8f4121a015c8e7233c2c049446);
#
#
#         var popup_ebf7c6b14f1e0da21bd10f7c88279221 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d37f72a4c75913b4284680ffa5ff3e77 = $(`&lt;div id=&quot;html_d37f72a4c75913b4284680ffa5ff3e77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_ebf7c6b14f1e0da21bd10f7c88279221.setContent(html_d37f72a4c75913b4284680ffa5ff3e77);
#
#
#
#         marker_3f4809678e3aa17630bd2603430416a0.bindPopup(popup_ebf7c6b14f1e0da21bd10f7c88279221)
#         ;
#
#
#
#
#             marker_3f4809678e3aa17630bd2603430416a0.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 장소명 보여줄게
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# import base64

# pic = base64.b64encode(open('./static/hotel.png','rb').read()).decode()
# image_tag = '<img src="data:image/jpeg;base64,{}">'.format(pic)
# iframe = folium.IFrame(image_tag, width=250, height=200)
# img_popup = folium.Popup(iframe, max_width=650)

# folium.Marker(
#     [37.5666805, 126.9784147], 
#     popup=img_popup, 
#     tooltip="클릭시 이미지보기",
#     icon=folium.Icon(color="red", icon="info-sign")
# ).add_to(map)
# map

# %% [markdown]
# ## CircleMarker

# %%
folium.CircleMarker(
    location= [37.5666805, 126.9784147], 
    radius=100,
    popup="<i>시청</i>", 
    color="#3186cc",
    fill=True,
    fill_color="#3186cc",
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_158799dfe2c797376ae551b0b58c5d6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_158799dfe2c797376ae551b0b58c5d6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_158799dfe2c797376ae551b0b58c5d6a = L.map(
#                 &quot;map_158799dfe2c797376ae551b0b58c5d6a&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d221f147f4365d091a99941ee9e64b70 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_158799dfe2c797376ae551b0b58c5d6a);
#
#
#             var marker_3f4809678e3aa17630bd2603430416a0 = L.marker(
#                 [37.5666805, 126.9784147],
#                 {}
#             ).addTo(map_158799dfe2c797376ae551b0b58c5d6a);
#
#
#             var icon_e7d15c8f4121a015c8e7233c2c049446 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3f4809678e3aa17630bd2603430416a0.setIcon(icon_e7d15c8f4121a015c8e7233c2c049446);
#
#
#         var popup_ebf7c6b14f1e0da21bd10f7c88279221 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d37f72a4c75913b4284680ffa5ff3e77 = $(`&lt;div id=&quot;html_d37f72a4c75913b4284680ffa5ff3e77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_ebf7c6b14f1e0da21bd10f7c88279221.setContent(html_d37f72a4c75913b4284680ffa5ff3e77);
#
#
#
#         marker_3f4809678e3aa17630bd2603430416a0.bindPopup(popup_ebf7c6b14f1e0da21bd10f7c88279221)
#         ;
#
#
#
#
#             marker_3f4809678e3aa17630bd2603430416a0.bindTooltip(
#                 `&lt;div&gt;
#                      클릭시 장소명 보여줄게
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_e5b5d1e3e245a7d7bb3ced1cbcb76098 = L.circleMarker(
#                 [37.5666805, 126.9784147],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_158799dfe2c797376ae551b0b58c5d6a);
#
#
#         var popup_7f618ef96ffc89c6ffa3e96ed3abc9b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e8ddeabaf0661bf871298caa6064947 = $(`&lt;div id=&quot;html_3e8ddeabaf0661bf871298caa6064947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;시청&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_7f618ef96ffc89c6ffa3e96ed3abc9b9.setContent(html_3e8ddeabaf0661bf871298caa6064947);
#
#
#
#         circle_marker_e5b5d1e3e245a7d7bb3ced1cbcb76098.bindPopup(popup_7f618ef96ffc89c6ffa3e96ed3abc9b9)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## MarkerCluster

# %%
from folium import plugins
# from folium.plugins import MarkerCluster

# %%
N = 50
lat_list = np.random.uniform(low=36, high=38, size=N)
lng_list = np.random.uniform(low=127, high=129, size=N)

geo_list = []
for i, lat in enumerate(lat_list):
    geo_list.append(  (lat_list[i], lng_list[i])  )

geo_list[:5]   

name_list = []
for i in range(N):
    name_list.append(  "빵집"+str(i)  )

    
map = folium.Map(location=[37.5666805, 126.9784147], zoom_start=6, 
                 tiles='OpenStreetMap')  #Stamen Terrain')
plugins.MarkerCluster(geo_list, popups=name_list).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5d859aeb8549e499ab7e19def62d887 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5d859aeb8549e499ab7e19def62d887&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5d859aeb8549e499ab7e19def62d887 = L.map(
#                 &quot;map_a5d859aeb8549e499ab7e19def62d887&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e38db9104134bae380a3c7c8e61342fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a5d859aeb8549e499ab7e19def62d887);
#
#
#             var marker_cluster_ebcec299c8b88b6ebd18ec27adbcca61 = L.markerClusterGroup(
#                 {}
#             );
#             map_a5d859aeb8549e499ab7e19def62d887.addLayer(marker_cluster_ebcec299c8b88b6ebd18ec27adbcca61);
#
#
#             var marker_0566c38f066df3efb6790b4c19297108 = L.marker(
#                 [36.38386954450457, 127.83793162687476],
#                 {}
#             ).addTo(marker_cluster_ebcec299c8b88b6ebd18ec27adbcca61);
#
#
#         var popup_8e7c4549139bf4b9c286e3685b0d6c25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4864bd9dd1df02105ae868b9b5ce5c01 = $(`&lt;div id=&quot;html_4864bd9dd1df02105ae868b9b5ce5c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집0&lt;/div&gt;`)[0];
#                 popup_8e7c4549139bf4b9c286e3685b0d6c25.setContent(html_4864bd9dd1df02105ae868b9b5ce5c01);
#
#
#
#         marker_0566c38f066df3efb6790b4c19297108.bindPopup(popup_8e7c4549139bf4b9c286e3685b0d6c25)
#         ;
#
#
#
#
#             var marker_093583a95c05119bcd2cbcb1226e002c = L.marker(
#                 [36.9065166704696, 128.97496037593027],
#                 {}
#             ).addTo(marker_cluster_ebcec299c8b88b6ebd18ec27adbcca61);
#
#
#         var popup_d4e69efc34f1b26344887680e329cffd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ffce6d1874a472a94d588474d5cb862 = $(`&lt;div id=&quot;html_2ffce6d1874a472a94d588474d5cb862&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집1&lt;/div&gt;`)[0];
#                 popup_d4e69efc34f1b26344887680e329cffd.setContent(html_2ffce6d1874a472a94d588474d5cb862);
#
#
#
#         marker_093583a95c05119bcd2cbcb1226e002c.bindPopup(popup_d4e69efc34f1b26344887680e329cffd)
#         ;
#
#
#
#
#             var marker_6ad8676dd1e543b226c076eab4378ae4 = L.marker(
#                 [37.506565313091556, 127.30441653956315],
#                 {}
#             ).addTo(marker_cluster_ebcec299c8b88b6ebd18ec27adbcca61);
#
#
#         var popup_beadc86f767c24d63f9105225c91f063 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90d7c2bbc4b2731ce8badfb317420d22 = $(`&lt;div id=&quot;html_90d7c2bbc4b2731ce8badfb317420d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집2&lt;/div&gt;`)[0];
#                 popup_beadc86f767c24d63f9105225c91f063.setContent(html_90d7c2bbc4b2731ce8badfb317420d22);
#
#
#
#         marker_6ad8676dd1e543b226c076eab4378ae4.bindPopup(popup_beadc86f767c24d63f9105225c91f063)
#         ;
#
#
#
#
#             var marker_a1c4a0428bf8ae63b159a5967284e8a0 = L.marker(
#                 [37.03935692847332, 127.39394538088149],
#                 {}
#             ).addTo(marker_cluster_ebcec299c8b88b6ebd18ec27adbcca61);
#
#
#         var popup_0a43e8ae4c9da62d4df870f1e4265b4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5a860c87106926de0e0eb20734feb18 = $(`&lt;div id=&quot;html_e5a860c87106926de0e0eb20734feb18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;빵집3&lt;/div&gt;`)[0];
#                 popup_0a43e8ae4c9da62d4df870f1e4265b4c.setContent(html_e5a860c87106926de0e0eb20734feb18);
#
#
#
#         marker_a1c4a0428bf8ae63b159a5967284e8a0.bindPopup(popup_0a43e8ae4c9da62d4df870f1e4265b4c)
#         ;
#
#
#
#
#             var marker_9a2893ebd8fb8e2f62eadc98147c352d = L.marker(
#                 [37.68531440668626, 127.92360391222526],
#                 {}

# %%
from folium.plugins import MarkerCluster

us_map = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(us_map)
folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

us_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89af581f88478a9ee641d9d9b8f0770c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89af581f88478a9ee641d9d9b8f0770c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89af581f88478a9ee641d9d9b8f0770c = L.map(
#                 &quot;map_89af581f88478a9ee641d9d9b8f0770c&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bc1f4464691d722ce8fb597473910e7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_89af581f88478a9ee641d9d9b8f0770c);
#
#
#             var marker_cluster_068da145186a8c68d3915e2c150c2614 = L.markerClusterGroup(
#                 {}
#             );
#             map_89af581f88478a9ee641d9d9b8f0770c.addLayer(marker_cluster_068da145186a8c68d3915e2c150c2614);
#
#
#             var marker_fc8a5e070af7e3efd4f13242e76c5100 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_068da145186a8c68d3915e2c150c2614);
#
#
#             var icon_365af6522dc3479792296ce0447ab465 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc8a5e070af7e3efd4f13242e76c5100.setIcon(icon_365af6522dc3479792296ce0447ab465);
#
#
#         var popup_f29fe08604bc83d9bd1293b5f173f376 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30e7cf8d3fb94a72fd664646294478ab = $(`&lt;div id=&quot;html_30e7cf8d3fb94a72fd664646294478ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_f29fe08604bc83d9bd1293b5f173f376.setContent(html_30e7cf8d3fb94a72fd664646294478ab);
#
#
#
#         marker_fc8a5e070af7e3efd4f13242e76c5100.bindPopup(popup_f29fe08604bc83d9bd1293b5f173f376)
#         ;
#
#
#
#
#             var marker_409dc39d13b8419f9ca9467812ad9a99 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_068da145186a8c68d3915e2c150c2614);
#
#
#             var icon_190ed5634858641d88f1f5b53823f150 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_409dc39d13b8419f9ca9467812ad9a99.setIcon(icon_190ed5634858641d88f1f5b53823f150);
#
#
#         var popup_e436baa2fbe4a29f2ef73a8cbe8367e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26d15bddc1eab41157e5608c4f7b92f7 = $(`&lt;div id=&quot;html_26d15bddc1eab41157e5608c4f7b92f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e436baa2fbe4a29f2ef73a8cbe8367e3.setContent(html_26d15bddc1eab41157e5608c4f7b92f7);
#
#
#
#         marker_409dc39d13b8419f9ca9467812ad9a99.bindPopup(popup_e436baa2fbe4a29f2ef73a8cbe8367e3)
#         ;
#
#
#
#
#             var marker_db0b6c3386bf721bd95b21c9d1a633ba = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_068da145186a8c68d3915e2c150c2614);
#
#
#         var popup_fa2ebd0806274b0b75d1fc7a4be89dc3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a20cc9592644f9faaeeb2ef69f11d9e8 = $(`&lt;div id=&quot;html_a20cc9592644f9faaeeb2ef69f11d9e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fa2ebd0806274b0b75d1fc7a4be89dc3.setContent(html_a20cc9592644f9faaeeb2ef69f11d9e8);
#
#
#
#         marker_db0b6c3386bf721bd95b21c9d1a633ba.bindPopup(popup_fa2ebd0806274b0b75d1fc7a4be89dc3)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !importa

# %% [markdown]
# # googlemap

# %%
gmaps = googlemaps.Client(key='AIzaSyCQWM6dFymuis1oh9DelTIPFO1igh1nVuo')

# %% [markdown]
# ## 주소 --> 위/경도
# * <font color=red><b> geocode("지명")

# %%
geocode_result = gmaps.geocode(('제주국제공항'), language='ko')
pprint.pprint(geocode_result)
# print(geocode_result)
# Out:
# [{'address_components': [{'long_name': '제주국제공항',
#                           'short_name': '제주국제공항',
#                           'types': ['airport',
#                                     'establishment',
#                                     'point_of_interest']},
#                          {'long_name': '2',
#                           'short_name': '2',
#                           'types': ['street_number']},
#                          {'long_name': '공항로',
#                           'short_name': '공항로',
#                           'types': ['political',
#                                     'sublocality',
#                                     'sublocality_level_4']},
#                          {'long_name': '제주시',
#                           'short_name': '제주시',
#                           'types': ['locality', 'political']},
#                          {'long_name': '제주특별자치도',
#                           'short_name': '제주특별자치도',
#                           'types': ['administrative_area_level_1',
#                                     'political']},
#                          {'long_name': '대한민국',
#                           'short_name': 'KR',
#                           'types': ['country', 'political']}],
#   'formatted_address': '대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)',
#   'geometry': {'location': {'lat': 33.51041350000001, 'lng': 126.4913534},
#                'location_type': 'ROOFTOP',
#                'viewport': {'northeast': {'lat': 33.51041350000001,
#                                           'lng': 126.4955668},
#                             'southwest': {'lat': 33.5059251,
#                                           'lng': 126.4913534}}},
#   'partial_match': True,
#   'place_id': 'ChIJxb_FCjv7DDURZ8wL9kMz_-0',
#   'plus_code': {'compound_code': '', 'global_code': '8Q58GF6R+5G'},
#   'types': ['airport', 'establishment', 'point_of_interest']}]

# %%
addr = geocode_result[0]['formatted_address']
lat  = geocode_result[0]['geometry']['location']['lat']
lang = geocode_result[0]['geometry']['location']['lng']

print("주소",addr)
print("위도",lat)
print("경도",lang)
# Out:
# 주소 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)
# 위도 33.51041350000001
# 경도 126.4913534

# %% [markdown]
# ## 위/경도 --> 주소
# * <font color=red><b>reverse_geocode((위도, 경도))

# %%
rg_res = gmaps.reverse_geocode( (33.51041350000001,126.4913534), language="ko")
type(rg_res), len(rg_res)
# Out:
# (list, 9)

# %%
rg_res[0]
# Out:
# {'address_components': [{'long_name': '제주국제공항',
#    'short_name': '제주국제공항',
#    'types': ['airport', 'establishment', 'point_of_interest']},
#   {'long_name': '2', 'short_name': '2', 'types': ['street_number']},
#   {'long_name': '공항로',
#    'short_name': '공항로',
#    'types': ['political', 'sublocality', 'sublocality_level_4']},
#   {'long_name': '제주시',
#    'short_name': '제주시',
#    'types': ['locality', 'political']},
#   {'long_name': '제주특별자치도',
#    'short_name': '제주특별자치도',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': '대한민국',
#    'short_name': 'KR',
#    'types': ['country', 'political']}],
#  'formatted_address': '대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU)',
#  'geometry': {'location': {'lat': 33.51041350000001, 'lng': 126.4913534},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 33.51176248029151,
#     'lng': 126.4927023802915},
#    'southwest': {'lat': 33.50906451970851, 'lng': 126.4900044197085}}},
#  'place_id': 'ChIJxb_FCjv7DDURZ8wL9kMz_-0',
#  'plus_code': {'global_code': '8Q58GF6R+5G'},
#  'types': ['airport', 'establishment', 'point_of_interest']}

# %%
for i in range(len(rg_res)) :
    addr = rg_res[i]['formatted_address'] 
    lat  = rg_res[i]['geometry']['location']['lat']
    lng  = rg_res[i]['geometry']['location']['lng']
    print(addr, lat, lng)
# Out:
# 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU) 33.51041350000001 126.4913534
# 8Q58GF6R+5G 33.51041350000001 126.4913534
# 대한민국 제주특별자치도 제주시 용담이동 833 33.5087187 126.4895311
# 대한민국 제주특별자치도 제주시 서해안로 33.5110314 126.4802212
# 대한민국 제주특별자치도 제주시 용담2동 33.5305996 126.4905278
# 대한민국 제주특별자치도 제주시 용담이동 33.5055121 126.4976769
# 대한민국 제주특별자치도 제주시 33.4996213 126.5311884
# 대한민국 제주특별자치도 33.4890113 126.4983023
# 대한민국 35.907757 127.766922

# %%
for i in range(len(rg_res)):
    addr = rg_res[i]['formatted_address']
    check = re.match('대한민국[\w\s]*', addr)
    d_addr = len(addr.split())
    if check and d_addr > 3:
        lat  = rg_res[i]['geometry']['location']['lat']
        lng  = rg_res[i]['geometry']['location']['lng']
        print(addr, lat, lng)
# Out:
# 대한민국 제주특별자치도 제주시 공항로 2 제주국제공항 (CJU) 33.51041350000001 126.4913534
# 대한민국 제주특별자치도 제주시 용담이동 833 33.5087187 126.4895311
# 대한민국 제주특별자치도 제주시 서해안로 33.5110314 126.4802212
# 대한민국 제주특별자치도 제주시 용담2동 33.5305996 126.4905278
# 대한민국 제주특별자치도 제주시 용담이동 33.5055121 126.4976769

# %% [markdown]
# # GeoJSON

# %% [markdown]
# ## choropleth()

# %%
# ! pip install geopandas

# %%
import geopandas as gpd
import folium
from folium import plugins

# %% [markdown]
# * [대한민국 지역구 GeoJSON]
#     * https://sgis.kostat.go.kr/view/index
#     * https://github.com/raqoon886/Local_HangJeongDong

# %%
state_geo = gpd.read_file('./datasets/seoul_geo_sigugun.json')
state_geo.head(2)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ./datasets/seoul_geo_sigugun.json: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 state_geo = gpd.read_file('./datasets/seoul_geo_sigugun.json')
#       2 state_geo.head(2)
#
# File C:\AI\pythonProject2\venv\lib\site-packages\geopandas\io\file.py:259, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     256     path_or_bytes = filename
#     258 if engine == "fiona":
# --> 259     return _read_file_fiona(
#     260         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     261     )
#     262 elif engine == "pyogrio":
#     263     return _read_file_pyogrio(
#     264         path_or_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     265     )
#
# File C:\AI\pythonProject2\venv\lib\site-packages\geopandas\io\file.py:303, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     300     reader = fiona.open
#     302 with fiona_env():
# --> 303     with reader(path_or_bytes, **kwargs) as features:
#     304         crs = features.crs_wkt
#     305         # attempt to get EPSG code
#
# File C:\AI\pythonProject2\venv\lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File C:\AI\pythonProject2\venv\lib\site-packages\fiona\__init__.py:365, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     362     path = parse_path(fp)
#     364 if mode in ("a", "r"):
# --> 365     colxn = Collection(
#     366         path,
#     367         mode,
#     368         driver=driver,
#     369         encoding=encoding,
#     370         layer=layer,
#     371         enabled_drivers=enabled_drivers,
#     372         allow_unsupported_drivers=allow_unsupported_drivers,
#     373         **kwargs
#     374     )
#     375 elif mode == "w":
#     376     colxn = Collection(
#     377         path,
#     378         mode,
#    (...)
#     387         **kwargs
#     388     )
#
# File C:\AI\pythonProject2\venv\lib\site-packages\fiona\collection.py:234, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     232 if self.mode == "r":
#     233     self.session = Session()
# --> 234     self.session.start(self, **kwargs)
#     235 elif self.mode in ("a", "w"):
#     236     self.session = WritingSession()
#
# File fiona\ogrext.pyx:587, in fiona.ogrext.Session.start()
#
# File fiona\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: ./datasets/seoul_geo_sigugun.json: No such file or directory

# %% [markdown]
# * [서울시 열린데이터 광장] 주민등록인구수
#     * https://data.seoul.go.kr/dataList/419/S/2/datasetView.do

# %%
seoul_ingu = pd.read_csv("./datasets/주민등록인구_20230222161234.csv", sep='\t', encoding='cp949')
seoul_ingu.head(2)

# %%
seoul_ingu.info()

# %%
# Initialize the map:
map = folium.Map(location=[37.562225, 126.978555], tiles="OpenStreetMap", zoom_start=10)

map.choropleth(
    geo_data=state_geo,
    name='인구밀도',
    
    data=seoul_ingu,
    columns=['동별', '총계'],
    
    key_on='feature.properties.name',
    fill_color=  'Blues' if state_geo["code"].str == '11250' else 'Reds',      # 'Blues',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'income'
)


plugins.MousePosition().add_to(map)

# # Save to html
# # m.save('kr_incode.html')
# # webbrowser.open_new("folium_kr.html")
map

# %% [markdown]
# ## GeoJson()

# %%
import json
with open('./datasets/seoul_geo_sigugun.json',mode='rt',encoding='utf-8') as f:
    geo = json.loads(f.read())
    f.close()

map = folium.Map(location=[37.562225, 126.978555], tiles="OpenStreetMap", zoom_start=10)
    
folium.GeoJson(
    geo,
    name='seoul_municipalities'
).add_to(map)
map

# %% [markdown]
# # RestAPI
# * https://www.data.go.kr/data/15049995/fileData.do?recommendDataYn=Y#tab-layer-openapi

# %%
import requests
import json

# %% [markdown]
# ## python json
# <pre>
# * load() <b>loads()</b> : 글자-->dic
# * dump() <b>dumps()</b> : dic -->글자

# %% [markdown]
# <font color=red size=3><b> json.loads() 사용시 :  반드시 더블쿼트 dic 데이터 사용

# %%
dic_str = """[  {"userid":"kim", "userpw":1111}, 
                {"userid":"lee", "userpw":2222}
             ]"""
print(dic_str , type(dic_str))


list_dic = json.loads(dic_str)
print(list_dic, type(list_dic))
print("비번:", list_dic[1]["userpw"])

# %%
list_dic = [{'userid': 'kim', 'userpw': 1111}, 
            {'userid': 'lee', 'userpw': 2222}
           ]
print(list_dic, type(list_dic))

list_dic_string = json.dumps(list_dic)
print(list_dic_string, type(list_dic_string))

# %% [markdown]
# ## RestAPI 호출

# %% [markdown]
# <pre>
# Curl
#
# curl -X GET "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page=1&perPage=10&serviceKey=fr%2B%2FkS%3D%3D"
#
# -H  "accept: application/json"
#
# -H  "Authorization: fr%2B%2FkS3Un%2BS%3D%3D"

# %% [markdown]
# ### 단일 호출

# %%
req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page=1&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
res = requests.get(req_url)
print(res)
print(res.status_code)
print(res.encoding)
print(type(res.text), res.text)

# %%
dic = json.loads(res.text)
dic

# %%
dic = json.loads(res.text)
# pprint.pprint(dic)
# pprint.pprint( dic["data"] )
for d in dic["data"]:
    lng = d["경도"]
    lat = d["위도"]
    sname = d["장소명"]
    print(lng, lat, sname)

# %% [markdown]
# ### 반복 호출

# %%
import time
import math
#------------------------------------------
start = time.time()
math.factorial(100000)
#------------------------------------------

total_len = 0
for i in range(1,3,1):
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    print(res.status_code)
    # print(type(res.text), res.text[:100])
    dic = json.loads(res.text)
    list_dic = dic['data']
    list_len = len(list_dic)
    total_len = total_len + list_len
    time.sleep(1) # 1초만
print("총:",total_len)    

#------------------------------------------
end = time.time()
print(f"{end - start:.5f} sec")
#------------------------------------------

# %% [markdown]
# #### DataFrame = list + dict
# * [{"aa":1, "bb":2},{"aa":22, "bb":33}]

# %%
import time
import math
# #------------------------------------------
# start = time.time()
# math.factorial(100000)
# #------------------------------------------

for i in range(1,3,1):
    time.sleep(1) # 1초만
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    # print(res.status_code)
    
    dic = json.loads(res.text)
    list_dic = dic['data']
# print(list_dic)    
df = pd.DataFrame(list_dic)
df = df[['위도','경도','장소명']].copy()
df.head(2)

# #------------------------------------------
# end = time.time()
# print(f"{end - start:.5f} sec")
# #------------------------------------------
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 12
#      10 page_no = str(i)
#      11 req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
# ---> 12 res = requests.get(req_url)
#      13 # print(res.status_code)
#      15 dic = json.loads(res.text)
#
# NameError: name 'requests' is not defined

# %%
df.info()

# %%
import time
import math


temp_list = []
for i in range(1,3,1):
    time.sleep(1) # 1초만
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    # print(res.status_code)
    
    dic = json.loads(res.text)
    list_dic = dic['data']
    
    for dic in  list_dic:
        temp_dic = {"위도":dic["위도"], "경도":dic["경도"], "장소명":dic["장소명"]}
        temp_list.append(temp_dic)

#print(temp_list)
# [{'위도': '33.4973684', '경도': '126.9460835', '장소명': '하고'}, 
#  {'위도': '33.4991412', '경도': '126.4940957', '장소명': '공항'}
# ] 
 
df = pd.DataFrame(temp_list)
df.head(2)

# %% [markdown]
# #### DataFrame = list + list
# * [[1, 2], [22, 33]]

# %%
import time
import math


temp_list = []
for i in range(1,3,1):
    time.sleep(1) # 1초만
    page_no = str(i)
    req_url = "https://api.odcloud.kr/api/15049995/v1/uddi:1a0d90fb-c631-4c81-93cb-9cf2f7bf968e?page="+page_no+"&perPage=10&serviceKey=fr%2B%2FkS3Un%2BSJKgd8kYfBLtMVGxEBJ%2BSo1IUoZ81W1%2F8wHyRlIgi2IZAvkznrxoifIGU8ZcdQWhsPtqxRzvd8Tw%3D%3D"
    res = requests.get(req_url)
    # print(res.status_code)
    
    dic = json.loads(res.text)
    list_dic = dic['data']
    
    for dic in  list_dic:
        mylist = [dic["위도"],dic["경도"], dic["장소명"]]
        temp_list.append(mylist)

# print(temp_list)
# [['33.4973684', '126.9460835', '하고'], 
#  ['33.4991412', '126.4940957', '공항']
# ]

df = pd.DataFrame(temp_list, columns=["위도","경도","장소명"])
df.head(2)

# %%
위도  경도   장소명
--- -----   ------

# %% [markdown]
# <font size=6><b>[실습] 제주 관광명소 GIS 시각화

# %% [markdown]
# # [실습] 제주 관광 GIS 시각화
# * [공공데이터포털] 제주관광공사_제주관광정보시스템(VISIT JEJU)_여행장소
#     * https://www.data.go.kr/data/15049995/fileData.do?recommendDataYn=Y

# %% [markdown]
# ## Data Load

# %%
dataset = pd.read_csv("./datasets/제주관광공사_여행장소_20220322.csv", encoding="cp949")
dataset.head(3)

# %%
dataset.info()

# %%
df = dataset[dataset['장소상세설명']=='숙소']
df.shape

# %% [markdown]
# ## Marker

# %%
map = folium.Map(location=[33.51041350000001,126.4913534], zoom_start=10)

geo_list = []
for i in range(len(df))[0:30]  :
    lat = df.iloc[i]['위도']
    lng = df.iloc[i]['경도']
    sname = df.iloc[i]['장소명']
    print(lat, lng, sname)
    geo_list.append( (lat,lng) )
    folium.Marker([lat, lng], popup=sname).add_to(map)
    
map

# %% [markdown]
# ## MarkerCluster

# %%
map = folium.Map(location=[33.41041350000001,126.4913534], zoom_start=10, 
                 tiles='OpenStreetMap')  #Stamen Terrain')
geo_list = []
name_list = []
for i in range(len(df))[:100] :
    lat = df.iloc[i]['위도']
    lng = df.iloc[i]['경도']
    sname = df.iloc[i]['장소명']
    # print(lat, lng, sname)
    geo_list.append( (lat,lng) )
    name_list.append(sname)
    
plugins.MarkerCluster(geo_list, popups=name_list).add_to(map)
map
